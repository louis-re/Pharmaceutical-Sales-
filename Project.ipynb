# %% [markdown]
# <a href="https://colab.research.google.com/github/louis-re/Pharmaceutical-Sales-/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
os.environ['KAGGLE_USERNAME'] = 'user'
os.environ['KAGGLE_KEY'] = 'key'

# %%
# !mkdir ~/.kaggle

# %%
# !kaggle datasets download -d milanzdravkovic/pharma-sales-data
# Out:
# ...
#   0% 0.00/352k [00:00<?, ?B/s]
# 100% 352k/352k [00:00<00:00, 93.4MB/s]

# %%
import zipfile

with zipfile.ZipFile('pharma-sales-data.zip', 'r') as zip_ref:
    zip_ref.extractall('data_folder')

# %%
data = pd.read_csv('data_folder/salesdaily.csv')

# %%
data.head()
# Out:
#       datum  M01AB  M01AE  N02BA  N02BE  N05B  N05C   R03  R06  Year  Month  \
# 0  1/2/2014    0.0   3.67    3.4  32.40   7.0   0.0   0.0  2.0  2014      1
# 1  1/3/2014    8.0   4.00    4.4  50.60  16.0   0.0  20.0  4.0  2014      1
# 2  1/4/2014    2.0   1.00    6.5  61.85  10.0   0.0   9.0  1.0  2014      1
# 3  1/5/2014    4.0   3.00    7.0  41.10   8.0   0.0   3.0  0.0  2014      1
# 4  1/6/2014    5.0   1.00    4.5  21.70  16.0   2.0   6.0  2.0  2014      1
#
#    Hour Weekday Name
# 0   248     Thursday
# 1   276       Friday
# 2   276     Saturday
# 3   276       Sunday
# 4   276       Monday

# %%
data.to_csv('pharma_data.csv', index=False)
